# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 
import numpy as np
from pandas.io.parsers import read_csv

model = tf.global_variables_initializer()

data = read_csv('correct_data.csv', sep=',')

xy = np.array(data,dtype=np.float32)

# %%
print(xy)
# Out:
# [[ 4.  6.  7.]
#  [ 5.  8.  8.]
#  [ 6.  4. 10.]
#  [ 5.  5.  9.]
#  [ 5.  2.  7.]
#  [ 5. 10. 10.]
#  [ 6. 10. 10.]
#  [ 7. 10. 10.]
#  [ 6.  3.  3.]
#  [ 5.  9.  9.]
#  [ 3. 10. 10.]
#  [ 4. 10. 10.]
#  [ 3. 10. 10.]
#  [ 4. 10. 10.]
#  [ 7. 10. 10.]
#  [ 6. 10. 10.]
#  [ 5.  3. 10.]
#  [ 5.  7.  9.]
#  [ 5.  6.  8.]
#  [ 5.  4.  7.]
#  [ 5.  4.  8.]
#  [ 4.  5.  4.]
#  [ 4.  4.  8.]
#  [ 6.  2.  3.]
#  [ 5.  4.  7.]
#  [ 6.  2.  4.]
#  [ 5.  2.  7.]
#  [ 4.  4.  7.]
#  [ 5. 10.  8.]
#  [ 6.  5.  2.]
#  [ 4.  4.  7.]
#  [ 5. 10.  7.]
#  [ 5. 10. 10.]
#  [ 5.  8.  9.]
#  [ 4.  4.  6.]
#  [ 5.  8.  8.]
#  [ 5.  3.  2.]
#  [ 6.  3.  7.]
#  [ 5.  5.  3.]
#  [ 3.  4.  8.]
#  [ 3.  4.  8.]
#  [ 4.  3.  7.]
#  [ 5.  2.  8.]
#  [ 6.  7. 10.]
#  [ 5.  6. 10.]
#  [ 4.  2.  6.]
#  [ 5.  3.  7.]
#  [ 4.  3.  6.]
#  [ 6.  3.  8.]
#  [ 5.  2.  7.]
#  [ 5.  3.  7.]
#  [ 2.  2.  7.]
#  [ 4.  1.  8.]
#  [ 5.  5.  6.]
#  [ 4.  2.  5.]
#  [ 4.  8.  9.]
#  [ 5.  6. 10.]
#  [ 6.  2.  4.]
#  [ 6.  8.  7.]
#  [ 3.  3.  6.]
#  [ 3.  7.  7.]
#  [ 5.  3.  9.]
#  [ 6.  9.  9.]
#  [ 6.  2.  6.]
#  [ 7.  4.  8.]
#  [ 4.  8.  2.]
#  [ 5.  4.  7.]
#  [ 6.  4.  8.]
#  [ 6.  4.  8.]
#  [ 4.  1.  5.]
#  [ 4.  2. 10.]
#  [ 6.  3. 10.]
#  [ 4.  9.  9.]
#  [ 3.  3. 10.]
#  [ 5.  4.  7.]
#  [ 4.  3. 10.]
#  [ 7.  1.  5.]
#  [ 5.  2.  7.]
#  [ 5.  3.  2.]
#  [ 6.  2.  8.]
#  [ 3.  4. 10.]
#  [ 4.  9.  8.]
#  [ 6.  3.  8.]
#  [ 5.  4.  4.]
#  [ 5.  4.  7.]
#  [ 5.  1.  4.]
#  [ 4.  5.  4.]
#  [ 6.  2.  5.]
#  [ 5.  4.  4.]
#  [ 7.  3.  6.]
#  [ 5.  4.  4.]
#  [ 6.  3.  8.]
#  [ 5.  8.  8.]
#  [ 8.  3.  2.]
#  [ 3. 10.  9.]]

# %%
#다변인 선형회귀 : 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델
#즉 각각의 가중치가 변인에 곱해지는 형식으로 식을 세워야 함

# %%
x_data = xy[:,0:-1]
y_data = xy[:,[-1]]

# %%
X = tf.placeholder(tf.float32,shape=[None,2])
Y = tf.placeholder(tf.float32,shape=[None,1])
W = tf.Variable(tf.random_normal([2,1]),name="weight")
b = tf.Variable(tf.random_normal([1]),name="bias")
#random_normal은 0과 1사이의 정규분포난수를 생성한다.

# %%
hypothesis = tf.matmul(X,W)+b
#tf.matmul은 3차원 이상의 행렬의 곱이다. 즉 X,W을 곱하라는 것이다.

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))
#reduce_mean은 시그마 기호(전체 원소 더한 값/원소 개수)

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.000005)
train = optimizer.minimize(cost)
#비용 최소화 코드 by경사하강법 이용

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(100001):
    cost_,hypo_,_,W_,b_ = sess.run([cost,hypothesis,train,W,b], feed_dict={X:x_data, Y:y_data})
    if step % 500 == 0:
        print("#",step,"손실 비용: ",cost_)
        print("-피로도: ",hypo_[0])
# Out:
# # 0 손실 비용:  543.67694
# -피로도:  [-16.334246]
# # 500 손실 비용:  319.53595
# -피로도:  [-10.934962]
# # 1000 손실 비용:  188.875
# -피로도:  [-6.810881]
# # 1500 손실 비용:  112.70227
# -피로도:  [-3.6604238]
# # 2000 손실 비용:  68.29002
# -피로도:  [-1.2533376]
# # 2500 손실 비용:  42.39062
# -피로도:  [0.5861813]
# # 3000 손실 비용:  27.282484
# -피로도:  [1.9923443]
# # 3500 손실 비용:  18.464924
# -피로도:  [3.0676098]
# # 4000 손실 비용:  13.314482
# -피로도:  [3.8902116]
# # 4500 손실 비용:  10.302014
# -피로도:  [4.5198727]
# # 5000 손실 비용:  8.536166
# -피로도:  [5.0021987]
# # 5500 손실 비용:  7.497392
# -피로도:  [5.3720026]
# # 6000 손실 비용:  6.8828325
# -피로도:  [5.655867]
# # 6500 손실 비용:  6.515951
# -피로도:  [5.8740797]
# # 7000 손실 비용:  6.2938156
# -피로도:  [6.0421395]
# # 7500 손실 비용:  6.156415
# -피로도:  [6.1718783]
# # 8000 손실 비용:  6.0687594
# -피로도:  [6.272324]
# # 8500 손실 비용:  6.010431
# -피로도:  [6.350377]
# # 9000 손실 비용:  5.969516
# -피로도:  [6.4113035]
# # 9500 손실 비용:  5.939056
# -피로도:  [6.4591227]
# # 10000 손실 비용:  5.914982
# -피로도:  [6.4969087]
# # 10500 손실 비용:  5.894905
# -피로도:  [6.527005]
# # 11000 손실 비용:  5.8774266
# -피로도:  [6.551203]
# # 11500 손실 비용:  5.8617144
# -피로도:  [6.57087]
# # 12000 손실 비용:  5.8472714
# -피로도:  [6.5870495]
# # 12500 손실 비용:  5.833801
# -피로도:  [6.600547]
# # 13000 손실 비용:  5.8211155
# -피로도:  [6.6119657]
# # 13500 손실 비용:  5.809103
# -피로도:  [6.6217866]
# # 14000 손실 비용:  5.7976723
# -피로도:  [6.630328]
# # 14500 손실 비용:  5.786787
# -피로도:  [6.63792]
# # 15000 손실 비용:  5.776386
# -피로도:  [6.6447163]
# # 15500 손실 비용:  5.7664504
# -피로도:  [6.650905]
# # 16000 손실 비용:  5.7569485
# -피로도:  [6.6565957]
# # 16500 손실 비용:  5.7478585
# -피로도:  [6.6619053]
# # 17000 손실 비용:  5.739162
# -피로도:  [6.666884]
# # 17500 손실 비용:  5.730837
# -피로도:  [6.6716065]
# # 18000 손실 비용:  5.7228694
# -피로도:  [6.6760983]
# # 18500 손실 비용:  5.715239
# -피로도:  [6.680406]
# # 19000 손실 비용:  5.7079315
# -피로도:  [6.684545]
# # 19500 손실 비용:  5.70093
# -피로도:  [6.688536]
# # 20000 손실 비용:  5.694223
# -피로도:  [6.6924005]
# # 20500 손실 비용:  5.687798
# -피로도:  [6.696151]
# # 21000 손실 비용:  5.68164
# -피로도:  [6.6997995]
# # 21500 손실 비용:  5.675739
# -피로도:  [6.7033453]
# # 22000 손실 비용:  5.6700797
# -피로도:  [6.7068024]
# # 22500 손실 비용:  5.6646543
# -피로도:  [6.71017]
# # 23000 손실 비용:  5.659449
# -피로도:  [6.7134604]
# # 23500 손실 비용:  5.6544566
# -피로도:  [6.7166657]
# # 24000 손실 비용:  5.6496654
# -피로도:  [6.7198014]
# # 24500 손실 비용:  5.6450696
# -피로도:  [6.722866]
# # 25000 손실 비용:  5.640657
# -피로도:  [6.7258644]
# # 25500 손실 비용:  5.63642
# -피로도:  [6.7287936]
# # 26000 손실 비용:  5.63235
# -피로도:  [6.7316537]
# # 26500 손실 비용:  5.628442
# -피로도:  [6.7344527]
# # 27000 손실 비용:  5.6246853
# -피로도:  [6.737198]
# # 27500 손실 비용:  5.621075
# -피로도:  [6.739866]
# # 28000 손실 비용:  5.617604
# -피로도:  [6.742498]
# # 28500 손실 비용:  5.6142654
# -피로도:  [6.74506]
# # 29000 손실 비용:  5.611055
# -피로도:  [6.7475715]
# # 29500 손실 비용:  5.6079626
# -피로도:  [6.750022]
# # 30000 손실 비용:  5.604991
# -피로도:  [6.752429]
# # 30500 손실 비용:  5.6021233
# -피로도:  [6.7547736]
# # 31000 손실 비용:  5.599365
# -피로도:  [6.757082]
# # 31500 손실 비용:  5.596708
# -피로도:  [6.759334]
# # 32000 손실 비용:  5.594142
# -피로도:  [6.761532]
# # 32500 손실 비용:  5.5916724
# -피로도:  [6.7636952]
# # 33000 손실 비용:  5.5892887
# -피로도:  [6.765814]
# # 33500 손실 비용:  5.5869865
# -피로도:  [6.7678804]
# # 34000 손실 비용:  5.5847664
# -피로도:  [6.7698965]
# # 34500 손실 비용:  5.5826206
# -피로도:  [6.771872]
# # 35000 손실 비용:  5.5805473
# -피로도:  [6.7738214]
# # 35500 손실 비용:  5.5785413
# -피로도:  [6.7757306]
# # 36000 손실 비용:  5.5766006
# -피로도:  [6.7776003]
# # 36500 손실 비용:  5.5747237
# -피로도:  [6.7794256]
# # 37000 손실 비용:  5.572909
# -피로도:  [6.781211]
# # 37500 손실 비용:  5.5711536
# -피로도:  [6.782949]
# # 38000 손실 비용:  5.569454
# -피로도:  [6.7846503]
# # 38500 손실 비용:  5.567808
# -피로도:  [6.7863173]
# # 39000 손실 비용:  5.56621
# -피로도:  [6.7879615]
# # 39500 손실 비용:  5.5646524
# -피로도:  [6.789574]
# # 40000 손실 비용:  5.563142
# -피로도:  [6.7911534]
# # 40500 손실 비용:  5.5616755
# -피로도:  [6.79269]
# # 41000 손실 비용:  5.560255
# -피로도:  [6.7942076]
# # 41500 손실 비용:  5.5588746
# -피로도:  [6.7956905]
# # 42000 손실 비용:  5.5575323
# -피로도:  [6.797138]
# # 42500 손실 비용:  5.5562277
# -피로도:  [6.798548]
# # 43000 손실 비용:  5.5549574
# -피로도:  [6.7999296]
# # 43500 손실 비용:  5.5537167
# -피로도:  [6.8013144]
# # 44000 손실 비용:  5.5525045
# -피로도:  [6.8026485]
# # 44500 손실 비용:  5.55132
# -피로도:  [6.8039703]
# # 45000 손실 비용:  5.5501647
# -피로도:  [6.805254]
# # 45500 손실 비용:  5.549042
# -피로도:  [6.806507]
# # 46000 손실 비용:  5.5479436
# -피로도:  [6.807763]
# # 46500 손실 비용:  5.5468707
# -피로도:  [6.808937]
# # 47000 손실 비용:  5.5458245
# -피로도:  [6.810131]
# # 47500 손실 비용:  5.544801
# -피로도:  [6.8113003]
# # 48000 손실 비용:  5.5438
# -피로도:  [6.812398]
# # 48500 손실 비용:  5.5428224
# -피로도:  [6.8135552]
# # 49000 손실 비용:  5.541864
# -피로도:  [6.8146067]
# # 49500 손실 비용:  5.5409136
# -피로도:  [6.815735]
# # 50000 손실 비용:  5.5399823
# -피로도:  [6.8167706]
# # 50500 손실 비용:  5.539067
# -피로도:  [6.8178434]
# # 51000 손실 비용:  5.5381722
# -피로도:  [6.8188376]
# # 51500 손실 비용:  5.537289
# -피로도:  [6.819851]
# # 52000 손실 비용:  5.5364265
# -피로도:  [6.820819]
# # 52500 손실 비용:  5.535575
# -피로도:  [6.8217726]
# # 53000 손실 비용:  5.5347414
# -피로도:  [6.8227253]
# # 53500 손실 비용:  5.5339193
# -피로도:  [6.8236194]
# # 54000 손실 비용:  5.5331106
# -피로도:  [6.82457]
# # 54500 손실 비용:  5.5323167
# -피로도:  [6.8254046]
# # 55000 손실 비용:  5.531533
# -피로도:  [6.8263097]
# # 55500 손실 비용:  5.5307617
# -피로도:  [6.827144]
# # 56000 손실 비용:  5.530001
# -피로도:  [6.8279576]
# # 56500 손실 비용:  5.5292506
# -피로도:  [6.828851]
# # 57000 손실 비용:  5.5285106
# -피로도:  [6.8295703]
# # 57500 손실 비용:  5.52778
# -피로도:  [6.830402]
# # 58000 손실 비용:  5.5270443
# -피로도:  [6.831236]
# # 58500 손실 비용:  5.5263195
# -피로도:  [6.831954]
# # 59000 손실 비용:  5.5256047
# -피로도:  [6.8327594]
# # 59500 손실 비용:  5.5248938
# -피로도:  [6.8335266]
# # 60000 손실 비용:  5.5241942
# -피로도:  [6.8342085]
# # 60500 손실 비용:  5.523502
# -피로도:  [6.8349533]
# # 61000 손실 비용:  5.5228124
# -피로도:  [6.8356986]
# # 61500 손실 비용:  5.522135
# -피로도:  [6.8363338]
# # 62000 손실 비용:  5.5214624
# -피로도:  [6.83702]
# # 62500 손실 비용:  5.520794
# -피로도:  [6.8377047]
# # 63000 손실 비용:  5.5201306
# -피로도:  [6.838368]
# # 63500 손실 비용:  5.519479
# -피로도:  [6.8389935]
# # 64000 손실 비용:  5.5188284
# -피로도:  [6.8396196]
# # 64500 손실 비용:  5.518181
# -피로도:  [6.8402452]
# # 65000 손실 비용:  5.5175433
# -피로도:  [6.840898]
# # 65500 손실 비용:  5.51691
# -피로도:  [6.841464]
# # 66000 손실 비용:  5.516279
# -피로도:  [6.8420305]
# # 66500 손실 비용:  5.515652
# -피로도:  [6.8426447]
# # 67000 손실 비용:  5.515033
# -피로도:  [6.8432746]
# # 67500 손실 비용:  5.5144167
# -피로도:  [6.843781]
# # 68000 손실 비용:  5.5138016
# -피로도:  [6.844288]
# # 68500 손실 비용:  5.513191
# -피로도:  [6.844853]
# # 69000 손실 비용:  5.5125866
# -피로도:  [6.845479]
# # 69500 손실 비용:  5.5119853
# -피로도:  [6.8459916]
# # 70000 손실 비용:  5.511386
# -피로도:  [6.846439]
# # 70500 손실 비용:  5.5107884
# -피로도:  [6.8469043]
# # 71000 손실 비용:  5.5101967
# -피로도:  [6.8474708]
# # 71500 손실 비용:  5.509607
# -피로도:  [6.848037]
# # 72000 손실 비용:  5.5090184
# -피로도:  [6.8485465]
# # 72500 손실 비용:  5.508434
# -피로도:  [6.8489337]
# # 73000 손실 비용:  5.5078464
# -피로도:  [6.849365]
# # 73500 손실 비용:  5.5072546
# -피로도:  [6.8499017]
# # 74000 손실 비용:  5.506665
# -피로도:  [6.850438]
# # 74500 손실 비용:  5.506076
# -피로도:  [6.8509746]
# # 75000 손실 비용:  5.505489
# -피로도:  [6.8513994]
# # 75500 손실 비용:  5.5049033
# -피로도:  [6.8517566]
# # 76000 손실 비용:  5.504321
# -피로도:  [6.852158]
# # 76500 손실 비용:  5.503742
# -피로도:  [6.852635]
# # 77000 손실 비용:  5.5031643
# -피로도:  [6.8531117]
# # 77500 손실 비용:  5.5025873
# -피로도:  [6.8535886]
# # 78000 손실 비용:  5.502011
# -피로도:  [6.8540654]
# # 78500 손실 비용:  5.5014358
# -피로도:  [6.8544044]
# # 79000 손실 비용:  5.500863
# -피로도:  [6.8547025]
# # 79500 손실 비용:  5.5002937
# -피로도:  [6.8550963]
# # 80000 손실 비용:  5.4997263
# -피로도:  [6.8555136]
# # 80500 손실 비용:  5.499159
# -피로도:  [6.855931]
# # 81000 손실 비용:  5.498593
# -피로도:  [6.856348]
# # 81500 손실 비용:  5.498027
# -피로도:  [6.8567653]
# # 82000 손실 비용:  5.4974623
# -피로도:  [6.8571825]
# # 82500 손실 비용:  5.4968967
# -피로도:  [6.857571]
# # 83000 손실 비용:  5.496334
# -피로도:  [6.857829]
# # 83500 손실 비용:  5.495775
# -피로도:  [6.8581777]
# # 84000 손실 비용:  5.4952173
# -피로도:  [6.8585353]
# # 84500 손실 비용:  5.49466
# -피로도:  [6.858893]
# # 85000 손실 비용:  5.4941034
# -피로도:  [6.8592505]
# # 85500 손실 비용:  5.4935455
# -피로도:  [6.859608]
# # 86000 손실 비용:  5.49299
# -피로도:  [6.859966]
# # 86500 손실 비용:  5.492434
# -피로도:  [6.8603234]
# # 87000 손실 비용:  5.491879
# -피로도:  [6.860681]
# # 87500 손실 비용:  5.491324
# -피로도:  [6.8610387]
# # 88000 손실 비용:  5.4907703
# -피로도:  [6.8613896]
# # 88500 손실 비용:  5.49022
# -피로도:  [6.8616877]
# # 89000 손실 비용:  5.4896708
# -피로도:  [6.8619857]
# # 89500 손실 비용:  5.4891224
# -피로도:  [6.8622837]
# # 90000 손실 비용:  5.488573
# -피로도:  [6.8625817]
# # 90500 손실 비용:  5.4880257
# -피로도:  [6.8628798]
# # 91000 손실 비용:  5.487477
# -피로도:  [6.863178]
# # 91500 손실 비용:  5.4869294
# -피로도:  [6.863476]
# # 92000 손실 비용:  5.4863806
# -피로도:  [6.863774]
# # 92500 손실 비용:  5.485834
# -피로도:  [6.864072]
# # 93000 손실 비용:  5.485287
# -피로도:  [6.86437]
# # 93500 손실 비용:  5.4847417
# -피로도:  [6.8647237]
# # 94000 손실 비용:  5.484198
# -피로도:  [6.8651114]
# # 94500 손실 비용:  5.483655
# -피로도:  [6.8654685]
# # 95000 손실 비용:  5.4831133
# -피로도:  [6.8657074]
# # 95500 손실 비용:  5.4825716
# -피로도:  [6.8659453]
# # 96000 손실 비용:  5.4820294
# -피로도:  [6.866184]
# # 96500 손실 비용:  5.481488
# -피로도:  [6.866422]
# # 97000 손실 비용:  5.4809475
# -피로도:  [6.866661]
# # 97500 손실 비용:  5.4804063
# -피로도:  [6.866899]
# # 98000 손실 비용:  5.4798646
# -피로도:  [6.867138]
# # 98500 손실 비용:  5.4793243
# -피로도:  [6.867376]
# # 99000 손실 비용:  5.478784
# -피로도:  [6.8676147]
# # 99500 손실 비용:  5.478244
# -피로도:  [6.8678527]
# # 100000 손실 비용:  5.477704
# -피로도:  [6.8680916]

# %%
print("가중치: ",W_)
print("편차: ",b_)
# Out:
# 가중치:  [[0.7605922]
#  [0.5306301]]
# 편차:  [0.64194226]

# %%
saver = tf.train.Saver()
#모든 변수들 저장
save_path = saver.save(sess,"./saved.cpkt")
#경로 지정
print("학습된 모델을 저장했습니다.")
# Out:
# 학습된 모델을 저장했습니다.

# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 
import numpy as np
from pandas.io.parsers import read_csv

model = tf.global_variables_initializer()

data = read_csv('sleep_fa.csv', sep=',')

xy = np.array(data,dtype=np.float32)
# Out:
# WARNING:tensorflow:From C:\Anaconda\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
print(xy)
# Out:
# [[ 4.  7.]
#  [ 5.  8.]
#  [ 6. 10.]
#  [ 5.  9.]
#  [ 5.  7.]
#  [10. 10.]
#  [10. 10.]
#  [10. 10.]
#  [ 6.  3.]
#  [10.  9.]
#  [10. 10.]
#  [10. 10.]
#  [10. 10.]
#  [10. 10.]
#  [ 9. 10.]
#  [10. 10.]
#  [ 5. 10.]
#  [ 5.  9.]
#  [ 5.  8.]
#  [ 5.  7.]
#  [ 5.  8.]
#  [ 4.  4.]
#  [ 4.  8.]
#  [ 6.  3.]
#  [ 5.  7.]
#  [ 6.  4.]
#  [ 5.  7.]
#  [ 4.  7.]
#  [ 5.  8.]
#  [ 6.  2.]
#  [ 4.  7.]
#  [ 5.  7.]
#  [ 5. 10.]
#  [ 5.  9.]
#  [ 4.  6.]
#  [ 5.  8.]
#  [ 5.  2.]
#  [ 6.  7.]
#  [ 5.  3.]
#  [ 3.  8.]
#  [ 3.  8.]
#  [ 4.  7.]
#  [ 5.  8.]
#  [ 6. 10.]
#  [ 5. 10.]
#  [ 4.  6.]
#  [ 5.  7.]
#  [ 4.  6.]
#  [ 6.  8.]
#  [ 5.  7.]
#  [ 5.  7.]
#  [ 2.  7.]
#  [ 4.  8.]
#  [ 5.  6.]
#  [ 4.  5.]
#  [ 4.  9.]
#  [ 5. 10.]
#  [ 6.  4.]
#  [ 6.  7.]
#  [ 3.  6.]
#  [ 3.  7.]
#  [ 5.  9.]
#  [ 6.  9.]
#  [ 6.  6.]
#  [ 7.  8.]
#  [ 4.  2.]
#  [ 5.  7.]
#  [ 6.  8.]
#  [ 6.  8.]
#  [ 4.  5.]
#  [ 4. 10.]
#  [ 6. 10.]
#  [ 4.  9.]
#  [ 3. 10.]
#  [ 5.  7.]
#  [ 4. 10.]
#  [ 7.  5.]
#  [ 5.  7.]
#  [ 5.  2.]
#  [ 6.  8.]
#  [ 3. 10.]
#  [ 4.  8.]
#  [ 6.  8.]
#  [ 5.  4.]
#  [ 5.  7.]
#  [ 5.  4.]
#  [ 4.  4.]
#  [ 6.  5.]
#  [ 5.  4.]
#  [ 7.  6.]
#  [ 5.  4.]
#  [ 6.  8.]
#  [ 5.  8.]
#  [ 8.  2.]
#  [ 3.  9.]]

# %%
x_data = xy[:,[0]]
y_data = xy[:,[-1]]

# %%
X = tf.placeholder(tf.float32,shape=[None,1])
Y = tf.placeholder(tf.float32,shape=[None,1])
W = tf.Variable(tf.random_normal([1,1],mean = -3,1),name="weight")
b = tf.Variable(tf.random_normal([1]),name="bias")

# %%
hypothesis = tf.matmul(X,W)+b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.000005)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(50001):
    cost_,hypo_,_ = sess.run([cost,hypothesis,train], feed_dict={X:x_data, Y:y_data})
    if step % 500 == 0:
        print("#",step,"손실 비용: ",cost_)
        print("-피로도: ",hypo_[0])
# Out:
# # 0 손실 비용:  498.80148
# -피로도:  [-10.7775545]
# # 500 손실 비용:  358.2004
# -피로도:  [-8.342776]
# # 1000 손실 비용:  257.89273
# -피로도:  [-6.2861247]
# # 1500 손실 비용:  186.33089
# -피로도:  [-4.5488496]
# # 2000 손실 비용:  135.2768
# -피로도:  [-3.081336]
# # 2500 손실 비용:  98.853165
# -피로도:  [-1.841671]
# # 3000 손실 비용:  72.86712
# -피로도:  [-0.7944558]
# # 3500 손실 비용:  54.327396
# -피로도:  [0.09020804]
# # 4000 손실 비용:  41.099964
# -피로도:  [0.8375753]
# # 4500 손실 비용:  31.662395
# -피로도:  [1.4689772]
# # 5000 손실 비용:  24.928598
# -피로도:  [2.002429]
# # 5500 손실 비용:  20.12368
# -피로도:  [2.453149]
# # 6000 손실 비용:  16.694866
# -피로도:  [2.8339908]
# # 6500 손실 비용:  14.247786
# -피로도:  [3.1558104]
# # 7000 손실 비용:  12.501096
# -피로도:  [3.4277756]
# # 7500 손실 비용:  11.254053
# -피로도:  [3.6576364]
# # 8000 손실 비용:  10.363488
# -피로도:  [3.85193]
# # 8500 손실 비용:  9.727233
# -피로도:  [4.016183]
# # 9000 손실 비용:  9.27241
# -피로도:  [4.1550617]
# # 9500 손실 비용:  8.947014
# -피로도:  [4.2725124]
# # 10000 손실 비용:  8.713964
# -피로도:  [4.3718596]
# # 10500 손실 비용:  8.546791
# -피로도:  [4.455919]
# # 11000 손실 비용:  8.42662
# -피로도:  [4.5270624]
# # 11500 손실 비용:  8.339979
# -피로도:  [4.5872984]
# # 12000 손실 비용:  8.277264
# -피로도:  [4.6383195]
# # 12500 손실 비용:  8.231614
# -피로도:  [4.6815596]
# # 13000 손실 비용:  8.198141
# -피로도:  [4.7182264]
# # 13500 손실 비용:  8.173357
# -피로도:  [4.749341]
# # 14000 손실 비용:  8.154772
# -피로도:  [4.775769]
# # 14500 손실 비용:  8.140611
# -피로도:  [4.798233]
# # 15000 손실 비용:  8.129603
# -피로도:  [4.8173547]
# # 15500 손실 비용:  8.120852
# -피로도:  [4.833646]
# # 16000 손실 비용:  8.1137085
# -피로도:  [4.8475537]
# # 16500 손실 비용:  8.107713
# -피로도:  [4.859443]
# # 17000 손실 비용:  8.102536
# -피로도:  [4.8696337]
# # 17500 손실 비용:  8.097947
# -피로도:  [4.878379]
# # 18000 손실 비용:  8.093776
# -피로도:  [4.885913]
# # 18500 손실 비용:  8.089905
# -피로도:  [4.8924174]
# # 19000 손실 비용:  8.086247
# -피로도:  [4.89806]
# # 19500 손실 비용:  8.082745
# -피로도:  [4.902964]
# # 20000 손실 비용:  8.079353
# -피로도:  [4.9072556]
# # 20500 손실 비용:  8.076041
# -피로도:  [4.9110193]
# # 21000 손실 비용:  8.072787
# -피로도:  [4.914344]
# # 21500 손실 비용:  8.069576
# -피로도:  [4.917294]
# # 22000 손실 비용:  8.066395
# -피로도:  [4.9199386]
# # 22500 손실 비용:  8.063237
# -피로도:  [4.922307]
# # 23000 손실 비용:  8.060097
# -피로도:  [4.9244394]
# # 23500 손실 비용:  8.056969
# -피로도:  [4.9263916]
# # 24000 손실 비용:  8.053853
# -피로도:  [4.9282184]
# # 24500 손실 비용:  8.050743
# -피로도:  [4.9298315]
# # 25000 손실 비용:  8.047642
# -피로도:  [4.931408]
# # 25500 손실 비용:  8.044545
# -피로도:  [4.9328356]
# # 26000 손실 비용:  8.0414505
# -피로도:  [4.9341636]
# # 26500 손실 비용:  8.038365
# -피로도:  [4.9354873]
# # 27000 손실 비용:  8.035286
# -피로도:  [4.936807]
# # 27500 손실 비용:  8.032204
# -피로도:  [4.937911]
# # 28000 손실 비용:  8.029123
# -피로도:  [4.9389873]
# # 28500 손실 비용:  8.02605
# -피로도:  [4.94006]
# # 29000 손실 비용:  8.022979
# -피로도:  [4.941131]
# # 29500 손실 비용:  8.019912
# -피로도:  [4.9422]
# # 30000 손실 비용:  8.01685
# -피로도:  [4.9432654]
# # 30500 손실 비용:  8.013793
# -피로도:  [4.9443293]
# # 31000 손실 비용:  8.010738
# -피로도:  [4.945391]
# # 31500 손실 비용:  8.0076885
# -피로도:  [4.9464498]
# # 32000 손실 비용:  8.0046425
# -피로도:  [4.947507]
# # 32500 손실 비용:  8.001599
# -피로도:  [4.9484963]
# # 33000 손실 비용:  7.9985538
# -피로도:  [4.949419]
# # 33500 손실 비용:  7.9955125
# -피로도:  [4.950341]
# # 34000 손실 비용:  7.9924746
# -피로도:  [4.951263]
# # 34500 손실 비용:  7.9894376
# -피로도:  [4.952184]
# # 35000 손실 비용:  7.9864025
# -피로도:  [4.9531054]
# # 35500 손실 비용:  7.9833765
# -피로도:  [4.9540253]
# # 36000 손실 비용:  7.9803524
# -피로도:  [4.9549437]
# # 36500 손실 비용:  7.9773307
# -피로도:  [4.955863]
# # 37000 손실 비용:  7.974308
# -피로도:  [4.956782]
# # 37500 손실 비용:  7.9712896
# -피로도:  [4.9577007]
# # 38000 손실 비용:  7.968277
# -피로도:  [4.9586186]
# # 38500 손실 비용:  7.9652677
# -피로도:  [4.959535]
# # 39000 손실 비용:  7.962261
# -피로도:  [4.960452]
# # 39500 손실 비용:  7.9592566
# -피로도:  [4.9613686]
# # 40000 손실 비용:  7.9562526
# -피로도:  [4.962285]
# # 40500 손실 비용:  7.953251
# -피로도:  [4.9632015]
# # 41000 손실 비용:  7.9502597
# -피로도:  [4.964115]
# # 41500 손실 비용:  7.947269
# -피로도:  [4.9650292]
# # 42000 손실 비용:  7.9442782
# -피로도:  [4.965943]
# # 42500 손실 비용:  7.94129
# -피로도:  [4.966857]
# # 43000 손실 비용:  7.938304
# -피로도:  [4.967771]
# # 43500 손실 비용:  7.935325
# -피로도:  [4.9686832]
# # 44000 손실 비용:  7.9323506
# -피로도:  [4.969595]
# # 44500 손실 비용:  7.9293766
# -피로도:  [4.970506]
# # 45000 손실 비용:  7.926403
# -피로도:  [4.9714174]
# # 45500 손실 비용:  7.923434
# -피로도:  [4.972329]
# # 46000 손실 비용:  7.9204674
# -피로도:  [4.9732394]
# # 46500 손실 비용:  7.9175076
# -피로도:  [4.9741483]
# # 47000 손실 비용:  7.914549
# -피로도:  [4.9750576]
# # 47500 손실 비용:  7.911592
# -피로도:  [4.9759665]
# # 48000 손실 비용:  7.9086366
# -피로도:  [4.9768753]
# # 48500 손실 비용:  7.905684
# -피로도:  [4.977784]
# # 49000 손실 비용:  7.902739
# -피로도:  [4.978691]
# # 49500 손실 비용:  7.8997955
# -피로도:  [4.9795976]
# # 50000 손실 비용:  7.8968544
# -피로도:  [4.980504]

# %%
saver = tf.train.Saver()
#모든 변수들 저장
save_path = saver.save(sess,"./simple/saved.cpkt")
#경로 지정
print("학습된 모델을 저장했습니다.")
# Out:
# 학습된 모델을 저장했습니다.

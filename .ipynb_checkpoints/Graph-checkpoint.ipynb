# %%
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
f = open ('4444_cor.csv')
data = csv.reader(f)

# %%
#x는 잠잔 시간,y는 휴대폰 사용 시간,z는 피로도
x = []
y = []
z = []

for row in data:
    int_row = [int(i) for i in row]
    print(int_row)
    x.append(int_row[0])
    y.append(int_row[1])
    z.append(int_row[2])
    
print(x)
print(y)
print(z)
    
fig = plt.figure(figsize=(9, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z,color = "r")

f.close
# Out:
# [4, 7]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-4f6ce9ba6c73> in <module>
#       9     x.append(int_row[0])
#      10     y.append(int_row[1])
# ---> 11     z.append(int_row[2])
#      12
#      13 print(x)
#
# IndexError: list index out of range

# %%
plt.scatter(x,z)
plt.show()

# %%
plt.scatter(y,z)
plt.show()

# %%
W = 0.5728485
b = 1.542709

x = np.linspace(0,10)
y = W*x + b

plt.plot(x,y,label = "f(x)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 
import numpy as np
from pandas.io.parsers import read_csv

model = tf.global_variables_initializer()

data = read_csv('correct_data.csv', sep=',')

xy = np.array(data,dtype=np.float32)
# Out:
# WARNING:tensorflow:From C:\Anaconda\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
print(xy)
# Out:
# [[ 4.  6.  7.]
#  [ 5.  8.  8.]
#  [ 6.  4. 10.]
#  [ 5.  5.  9.]
#  [ 5.  2.  7.]
#  [ 5. 10. 10.]
#  [ 6. 10. 10.]
#  [ 7. 10. 10.]
#  [ 6.  3.  3.]
#  [ 5.  9.  9.]
#  [ 3. 10. 10.]
#  [ 4. 10. 10.]
#  [ 3. 10. 10.]
#  [ 4. 10. 10.]
#  [ 7. 10. 10.]
#  [ 6. 10. 10.]
#  [ 5.  3. 10.]
#  [ 5.  7.  9.]
#  [ 5.  6.  8.]
#  [ 5.  4.  7.]
#  [ 5.  4.  8.]
#  [ 4.  5.  4.]
#  [ 4.  4.  8.]
#  [ 6.  2.  3.]
#  [ 5.  4.  7.]
#  [ 6.  2.  4.]
#  [ 5.  2.  7.]
#  [ 4.  4.  7.]
#  [ 5. 10.  8.]
#  [ 6.  5.  2.]
#  [ 4.  4.  7.]
#  [ 5. 10.  7.]
#  [ 5. 10. 10.]
#  [ 5.  8.  9.]
#  [ 4.  4.  6.]
#  [ 5.  8.  8.]
#  [ 5.  3.  2.]
#  [ 6.  3.  7.]
#  [ 5.  5.  3.]
#  [ 3.  4.  8.]
#  [ 3.  4.  8.]
#  [ 4.  3.  7.]
#  [ 5.  2.  8.]
#  [ 6.  7. 10.]
#  [ 5.  6. 10.]
#  [ 4.  2.  6.]
#  [ 5.  3.  7.]
#  [ 4.  3.  6.]
#  [ 6.  3.  8.]
#  [ 5.  2.  7.]
#  [ 5.  3.  7.]
#  [ 2.  2.  7.]
#  [ 4.  1.  8.]
#  [ 5.  5.  6.]
#  [ 4.  2.  5.]
#  [ 4.  8.  9.]
#  [ 5.  6. 10.]
#  [ 6.  2.  4.]
#  [ 6.  8.  7.]
#  [ 3.  3.  6.]
#  [ 3.  7.  7.]
#  [ 5.  3.  9.]
#  [ 6.  9.  9.]
#  [ 6.  2.  6.]
#  [ 7.  4.  8.]
#  [ 4.  8.  2.]
#  [ 5.  4.  7.]
#  [ 6.  4.  8.]
#  [ 6.  4.  8.]
#  [ 4.  1.  5.]
#  [ 4.  2. 10.]
#  [ 6.  3. 10.]
#  [ 4.  9.  9.]
#  [ 3.  3. 10.]
#  [ 5.  4.  7.]
#  [ 4.  3. 10.]
#  [ 7.  1.  5.]
#  [ 5.  2.  7.]
#  [ 5.  3.  2.]
#  [ 6.  2.  8.]
#  [ 3.  4. 10.]
#  [ 4.  9.  8.]
#  [ 6.  3.  8.]
#  [ 5.  4.  4.]
#  [ 5.  4.  7.]
#  [ 5.  1.  4.]
#  [ 4.  5.  4.]
#  [ 6.  2.  5.]
#  [ 5.  4.  4.]
#  [ 7.  3.  6.]
#  [ 5.  4.  4.]
#  [ 6.  3.  8.]
#  [ 5.  8.  8.]
#  [ 8.  3.  2.]
#  [ 3. 10.  9.]]

# %%
#다변인 선형회귀 : 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델
#즉 각각의 가중치가 변인에 곱해지는 형식으로 식을 세워야 함

# %%
x_data = xy[:,0:-1]
y_data = xy[:,[-1]]

# %%
X = tf.placeholder(tf.float32,shape=[None,2])
Y = tf.placeholder(tf.float32,shape=[None,1])
W = tf.Variable(tf.random_normal([2,1]),name="weight")
b = tf.Variable(tf.random_normal([1]),name="bias")
#random_normal은 0과 1사이의 정규분포난수를 생성한다.

# %%
hypothesis = tf.matmul(X,W)+b
#tf.matmul은 3차원 이상의 행렬의 곱이다. 즉 X,W을 곱하라는 것이다.

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))
#reduce_mean은 시그마 기호(전체 원소 더한 값/원소 개수)

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.000005)
train = optimizer.minimize(cost)
#비용 최소화 코드 by경사하강법 이용

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(100001):
    cost_,hypo_,_,W_,b_ = sess.run([cost,hypothesis,train,W,b], feed_dict={X:x_data, Y:y_data})
    if step % 500 == 0:
        print("#",step,"손실 비용: ",cost_)
        print("-피로도: ",hypo_[0])
# Out:
# # 0 손실 비용:  113.190765
# -피로도:  [-4.1734457]
# # 500 손실 비용:  70.00065
# -피로도:  [-1.792918]
# # 1000 손실 비용:  44.76247
# -피로도:  [0.02855587]
# # 1500 손실 비용:  29.990883
# -피로도:  [1.4231254]
# # 2000 손실 비용:  21.322798
# -피로도:  [2.491678]
# # 2500 손실 비용:  16.21494
# -피로도:  [3.3112402]
# # 3000 손실 비용:  13.1847515
# -피로도:  [3.940627]
# # 3500 손실 비용:  11.368008
# -피로도:  [4.424734]
# # 4000 손실 비용:  10.260854
# -피로도:  [4.797837]
# # 4500 손실 비용:  9.569468
# -피로도:  [5.086122]
# # 5000 손실 비용:  9.122516
# -피로도:  [5.309569]
# # 5500 손실 비용:  8.820028
# -피로도:  [5.4834366]
# # 6000 손실 비용:  8.603643
# -피로도:  [5.619383]
# # 6500 손실 비용:  8.439259
# -피로도:  [5.726304]
# # 7000 손실 비용:  8.306914
# -피로도:  [5.810993]
# # 7500 손실 비용:  8.194898
# -피로도:  [5.878639]
# # 8000 손실 비용:  8.096303
# -피로도:  [5.9332066]
# # 8500 손실 비용:  8.00704
# -피로도:  [5.9777236]
# # 9000 손실 비용:  7.9246454
# -피로도:  [6.014497]
# # 9500 손실 비용:  7.847629
# -피로도:  [6.045302]
# # 10000 손실 비용:  7.775059
# -피로도:  [6.071495]
# # 10500 손실 비용:  7.7063117
# -피로도:  [6.0940843]
# # 11000 손실 비용:  7.6410136
# -피로도:  [6.1139007]
# # 11500 손실 비용:  7.57883
# -피로도:  [6.131508]
# # 12000 손실 비용:  7.5195613
# -피로도:  [6.147384]
# # 12500 손실 비용:  7.463023
# -피로도:  [6.1618743]
# # 13000 손실 비용:  7.40907
# -피로도:  [6.1752667]
# # 13500 손실 비용:  7.3575544
# -피로도:  [6.187754]
# # 14000 손실 비용:  7.308375
# -피로도:  [6.1995225]
# # 14500 손실 비용:  7.2613964
# -피로도:  [6.210659]
# # 15000 손실 비용:  7.2165413
# -피로도:  [6.221301]
# # 15500 손실 비용:  7.173693
# -피로도:  [6.2314963]
# # 16000 손실 비용:  7.132757
# -피로도:  [6.241297]
# # 16500 손실 비용:  7.0936627
# -피로도:  [6.2507696]
# # 17000 손실 비용:  7.056311
# -피로도:  [6.259943]
# # 17500 손실 비용:  7.020617
# -피로도:  [6.268827]
# # 18000 손실 비용:  6.98653
# -피로도:  [6.277475]
# # 18500 손실 비용:  6.9539485
# -피로도:  [6.2858763]
# # 19000 손실 비용:  6.9228244
# -피로도:  [6.294072]
# # 19500 손실 비용:  6.8930726
# -피로도:  [6.302041]
# # 20000 손실 비용:  6.8646536
# -피로도:  [6.309836]
# # 20500 손실 비용:  6.8374834
# -피로도:  [6.3174295]
# # 21000 손실 비용:  6.811516
# -피로도:  [6.3248367]
# # 21500 손실 비용:  6.7867007
# -피로도:  [6.332089]
# # 22000 손실 비용:  6.7629795
# -피로도:  [6.339165]
# # 22500 손실 비용:  6.740301
# -피로도:  [6.3460703]
# # 23000 손실 비용:  6.718617
# -피로도:  [6.352828]
# # 23500 손실 비용:  6.6978865
# -피로도:  [6.3594203]
# # 24000 손실 비용:  6.678063
# -피로도:  [6.365875]
# # 24500 손실 비용:  6.659109
# -피로도:  [6.37218]
# # 25000 손실 비용:  6.6409807
# -피로도:  [6.3783474]
# # 25500 손실 비용:  6.6236424
# -피로도:  [6.384375]
# # 26000 손실 비용:  6.6070557
# -피로도:  [6.390264]
# # 26500 손실 비용:  6.5911846
# -피로도:  [6.396017]
# # 27000 손실 비용:  6.576005
# -피로도:  [6.4016504]
# # 27500 손실 비용:  6.5614834
# -피로도:  [6.407164]
# # 28000 손실 비용:  6.5475793
# -피로도:  [6.4125457]
# # 28500 손실 비용:  6.5342755
# -피로도:  [6.4178047]
# # 29000 손실 비용:  6.521542
# -피로도:  [6.4229665]
# # 29500 손실 비용:  6.5093455
# -피로도:  [6.4279776]
# # 30000 손실 비용:  6.497677
# -피로도:  [6.4329257]
# # 30500 손실 비용:  6.486492
# -피로도:  [6.4377217]
# # 31000 손실 비용:  6.4757934
# -피로도:  [6.4424486]
# # 31500 손실 비용:  6.4655337
# -피로도:  [6.4470496]
# # 32000 손실 비용:  6.455712
# -피로도:  [6.451549]
# # 32500 손실 비용:  6.4462976
# -피로도:  [6.4559684]
# # 33000 손실 비용:  6.43727
# -피로도:  [6.4602647]
# # 33500 손실 비용:  6.4286256
# -피로도:  [6.464475]
# # 34000 손실 비용:  6.420333
# -피로도:  [6.4686165]
# # 34500 손실 비용:  6.412381
# -피로도:  [6.4726486]
# # 35000 손실 비용:  6.4047556
# -피로도:  [6.4765754]
# # 35500 손실 비용:  6.3974314
# -피로도:  [6.480429]
# # 36000 손실 비용:  6.3904157
# -피로도:  [6.484216]
# # 36500 손실 비용:  6.383685
# -피로도:  [6.4879074]
# # 37000 손실 비용:  6.3772154
# -피로도:  [6.4915338]
# # 37500 손실 비용:  6.3710046
# -피로도:  [6.4950733]
# # 38000 손실 비용:  6.365042
# -피로도:  [6.4985275]
# # 38500 손실 비용:  6.359314
# -피로도:  [6.50191]
# # 39000 손실 비용:  6.353804
# -피로도:  [6.50523]
# # 39500 손실 비용:  6.3485126
# -피로도:  [6.5084667]
# # 40000 손실 비용:  6.3434267
# -피로도:  [6.511631]
# # 40500 손실 비용:  6.338531
# -피로도:  [6.5147343]
# # 41000 손실 비용:  6.3338194
# -피로도:  [6.51777]
# # 41500 손실 비용:  6.329286
# -피로도:  [6.5207286]
# # 42000 손실 비용:  6.324924
# -피로도:  [6.523616]
# # 42500 손실 비용:  6.320729
# -피로도:  [6.526481]
# # 43000 손실 비용:  6.3166814
# -피로도:  [6.529287]
# # 43500 손실 비용:  6.312782
# -피로도:  [6.5320163]
# # 44000 손실 비용:  6.3090243
# -피로도:  [6.5346704]
# # 44500 손실 비용:  6.305399
# -피로도:  [6.5372496]
# # 45000 손실 비용:  6.3019023
# -피로도:  [6.539841]
# # 45500 손실 비용:  6.2985287
# -피로도:  [6.542353]
# # 46000 손실 비용:  6.2952676
# -피로도:  [6.544794]
# # 46500 손실 비용:  6.292118
# -피로도:  [6.5471816]
# # 47000 손실 비용:  6.2890882
# -피로도:  [6.5495367]
# # 47500 손실 비용:  6.286146
# -피로도:  [6.5518336]
# # 48000 손실 비용:  6.2832956
# -피로도:  [6.554066]
# # 48500 손실 비용:  6.280549
# -피로도:  [6.5563107]
# # 49000 손실 비용:  6.2778845
# -피로도:  [6.5584545]
# # 49500 손실 비용:  6.2753096
# -피로도:  [6.560567]
# # 50000 손실 비용:  6.2728195
# -피로도:  [6.5626507]
# # 50500 손실 비용:  6.270387
# -피로도:  [6.5646415]
# # 51000 손실 비용:  6.268043
# -피로도:  [6.566683]
# # 51500 손실 비용:  6.2657547
# -피로도:  [6.568602]
# # 52000 손실 비용:  6.2635484
# -피로도:  [6.5705385]
# # 52500 손실 비용:  6.2614
# -피로도:  [6.572376]
# # 53000 손실 비용:  6.2593193
# -피로도:  [6.574207]
# # 53500 손실 비용:  6.257295
# -피로도:  [6.575973]
# # 54000 손실 비용:  6.2553215
# -피로도:  [6.5777416]
# # 54500 손실 비용:  6.253392
# -피로도:  [6.579458]
# # 55000 손실 비용:  6.2515216
# -피로도:  [6.5811696]
# # 55500 손실 비용:  6.249691
# -피로도:  [6.582803]
# # 56000 손실 비용:  6.2479196
# -피로도:  [6.5844717]
# # 56500 손실 비용:  6.246181
# -피로도:  [6.585966]
# # 57000 손실 비용:  6.2445035
# -피로도:  [6.587577]
# # 57500 손실 비용:  6.242853
# -피로도:  [6.5890656]
# # 58000 손실 비용:  6.2412467
# -피로도:  [6.590596]
# # 58500 손실 비용:  6.239667
# -피로도:  [6.592062]
# # 59000 손실 비용:  6.2381134
# -피로도:  [6.5934505]
# # 59500 손실 비용:  6.236608
# -피로도:  [6.5949435]
# # 60000 손실 비용:  6.2351274
# -피로도:  [6.5962844]
# # 60500 손실 비용:  6.23368
# -피로도:  [6.5976305]
# # 61000 손실 비용:  6.2322664
# -피로도:  [6.5990148]
# # 61500 손실 비용:  6.230875
# -피로도:  [6.600237]
# # 62000 손실 비용:  6.2295175
# -피로도:  [6.601543]
# # 62500 손실 비용:  6.228186
# -피로도:  [6.6028247]
# # 63000 손실 비용:  6.226874
# -피로도:  [6.603972]
# # 63500 손실 비용:  6.2255845
# -피로도:  [6.605238]
# # 64000 손실 비용:  6.2243147
# -피로도:  [6.6064386]
# # 64500 손실 비용:  6.2230563
# -피로도:  [6.6076]
# # 65000 손실 비용:  6.221822
# -피로도:  [6.608691]
# # 65500 손실 비용:  6.220615
# -피로도:  [6.6098905]
# # 66000 손실 비용:  6.219423
# -피로도:  [6.6109633]
# # 66500 손실 비용:  6.2182393
# -피로도:  [6.612001]
# # 67000 손실 비용:  6.2170873
# -피로도:  [6.6130776]
# # 67500 손실 비용:  6.215951
# -피로도:  [6.6141715]
# # 68000 손실 비용:  6.214825
# -피로도:  [6.615125]
# # 68500 손실 비용:  6.213708
# -피로도:  [6.616079]
# # 69000 손실 비용:  6.212621
# -피로도:  [6.6171136]
# # 69500 손실 비용:  6.2115455
# -피로도:  [6.6181264]
# # 70000 손실 비용:  6.2104783
# -피로도:  [6.6190214]
# # 70500 손실 비용:  6.2094193
# -피로도:  [6.619856]
# # 71000 손실 비용:  6.2083817
# -피로도:  [6.620873]
# # 71500 손실 비용:  6.207344
# -피로도:  [6.6217957]
# # 72000 손실 비용:  6.206311
# -피로도:  [6.6227193]
# # 72500 손실 비용:  6.2052865
# -피로도:  [6.6235323]
# # 73000 손실 비용:  6.204268
# -피로도:  [6.624286]
# # 73500 손실 비용:  6.203273
# -피로도:  [6.62527]
# # 74000 손실 비용:  6.202286
# -피로도:  [6.6261063]
# # 74500 손실 비용:  6.2013025
# -피로도:  [6.626911]
# # 75000 손실 비용:  6.2003245
# -피로도:  [6.6277156]
# # 75500 손실 비용:  6.1993523
# -피로도:  [6.628377]
# # 76000 손실 비용:  6.198399
# -피로도:  [6.62918]
# # 76500 손실 비용:  6.197451
# -피로도:  [6.6300445]
# # 77000 손실 비용:  6.1965113
# -피로도:  [6.630776]
# # 77500 손실 비용:  6.1955757
# -피로도:  [6.6314616]
# # 78000 손실 비용:  6.194643
# -피로도:  [6.632147]
# # 78500 손실 비용:  6.1937127
# -피로도:  [6.6328325]
# # 79000 손실 비용:  6.1927986
# -피로도:  [6.6335487]
# # 79500 손실 비용:  6.191893
# -피로도:  [6.634294]
# # 80000 손실 비용:  6.1909895
# -피로도:  [6.635039]
# # 80500 손실 비용:  6.1900907
# -피로도:  [6.6356745]
# # 81000 손실 비용:  6.1891956
# -피로도:  [6.636241]
# # 81500 손실 비용:  6.188305
# -피로도:  [6.6368527]
# # 82000 손실 비용:  6.1874223
# -피로도:  [6.637538]
# # 82500 손실 비용:  6.1865396
# -피로도:  [6.638195]
# # 83000 손실 비용:  6.1856637
# -피로도:  [6.6387014]
# # 83500 손실 비용:  6.184794
# -피로도:  [6.6392946]
# # 84000 손실 비용:  6.183928
# -피로도:  [6.63992]
# # 84500 손실 비용:  6.1830635
# -피로도:  [6.6405463]
# # 85000 손실 비용:  6.1821866
# -피로도:  [6.641129]
# # 85500 손실 비용:  6.1813164
# -피로도:  [6.641665]
# # 86000 손실 비용:  6.180449
# -피로도:  [6.642261]
# # 86500 손실 비용:  6.1795826
# -피로도:  [6.642857]
# # 87000 손실 비용:  6.178718
# -피로도:  [6.643453]
# # 87500 손실 비용:  6.177857
# -피로도:  [6.6439614]
# # 88000 손실 비용:  6.1770024
# -피로도:  [6.64446]
# # 88500 손실 비용:  6.176151
# -피로도:  [6.6449966]
# # 89000 손실 비용:  6.1753
# -피로도:  [6.645533]
# # 89500 손실 비용:  6.174449
# -피로도:  [6.6460695]
# # 90000 손실 비용:  6.173602
# -피로도:  [6.646606]
# # 90500 손실 비용:  6.1727567
# -피로도:  [6.6470814]
# # 91000 손실 비용:  6.171918
# -피로도:  [6.647558]
# # 91500 손실 비용:  6.17108
# -피로도:  [6.648035]
# # 92000 손실 비용:  6.1702433
# -피로도:  [6.648512]
# # 92500 손실 비용:  6.1694074
# -피로도:  [6.6489887]
# # 93000 손실 비용:  6.1685715
# -피로도:  [6.6494656]
# # 93500 손실 비용:  6.1677394
# -피로도:  [6.6500077]
# # 94000 손실 비용:  6.166913
# -피로도:  [6.650444]
# # 94500 손실 비용:  6.166086
# -피로도:  [6.6508613]
# # 95000 손실 비용:  6.1652613
# -피로도:  [6.6512785]
# # 95500 손실 비용:  6.1644373
# -피로도:  [6.6516957]
# # 96000 손실 비용:  6.163613
# -피로도:  [6.652113]
# # 96500 손실 비용:  6.1627903
# -피로도:  [6.652539]
# # 97000 손실 비용:  6.161973
# -피로도:  [6.653075]
# # 97500 손실 비용:  6.1611567
# -피로도:  [6.653574]
# # 98000 손실 비용:  6.1603413
# -피로도:  [6.6539316]
# # 98500 손실 비용:  6.159526
# -피로도:  [6.6542892]
# # 99000 손실 비용:  6.1587124
# -피로도:  [6.654647]
# # 99500 손실 비용:  6.157898
# -피로도:  [6.6550045]
# # 100000 손실 비용:  6.1570854
# -피로도:  [6.655362]

# %%
print("가중치: ",W_)
print("편차: ",b_)
# Out:
# 가중치:  [[0.98142856]
#  [0.5654063 ]]
# 편차:  [-0.6627896]

# %%
saver = tf.train.Saver()
#모든 변수들 저장
save_path = saver.save(sess,"./saved.cpkt")
#경로 지정
print("학습된 모델을 저장했습니다.")
# Out:
# 학습된 모델을 저장했습니다.
